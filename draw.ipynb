# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

data = [[[-16.85804392], [32.64848576], [385.1187528]],
        [[71.68288588], [-7.16774538], [361.50253504]],
        [[-28.17072218], [18.42517522], [373.90951544]],
        [[52.37980313], [14.96532302], [375.81807926]],
        [[-103.42867136], [8.09679718], [364.43933692]],
        [[-16.63548105], [47.60643203], [395.81935074]],
        [[10.53441137], [52.05104448], [399.8819718]],
        [[100.56825266], [14.50076422], [377.96048494]],
        [[19.29668565], [46.88715869], [397.04303095]],
        [[98.28213669], [-33.24405049], [344.50669529]],
        [[-80.92646751], [-26.11678872], [341.10039059]],
        [[-6.21431265], [52.06994794], [399.58059518]],
        [[-48.61538746], [56.71205197], [400.75295569]],
        [[36.96334399], [56.48384698], [404.5470027]],
        [[-57.14573448], [56.78940564], [400.47615]],
        [[35.34829271], [56.26574369], [404.24856513]],
        [[-23.94863421], [56.71791898], [401.62018858]],
        [[68.77237033], [56.93893487], [406.11377215]],
        [[-19.82737275], [28.15177043], [381.88278809]],
        [[62.90727826], [27.34458544], [385.38380206]],
        [[-39.12262822], [18.13670997], [373.57013941]],
        [[53.44946026], [36.52672749], [391.25166872]],
        [[-20.1570564], [48.31941446], [395.99931775]],
        [[70.85073187], [11.53855561], [374.62028339]],
        [[-21.05313702], [12.21103872], [370.22304073]],
        [[59.54800013], [11.29571903], [373.79854018]],
        [[-37.8972917], [1.19571008], [361.86977174]],
        [[48.56823323], [28.10457812], [385.04203303]]]

arr = np.array(data)
arr = arr[:,:,0]
# 创建一个三维图形对象
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# x = np.linspace(-105, 105, 1000)
# y = np.linspace(-35, 65, 1000)
# X, Y = np.meshgrid(x, y)

# # 定义平面方程
# Z = 0.04649940105993022*X + 0.7022479002697639*Y +363.0142033514434
# # 绘制平面
# ax.plot_surface(X, Y, Z, cmap='viridis')

# 绘制折线图
for i in range(0, len(data), 2):
    x = [arr[i][0], arr[i+1][0]]
    y = [arr[i][1], arr[i+1][1]]
    z = [arr[i][2], arr[i+1][2]]
    ax.plot(x, y, z,color= 'r')



# 设置坐标轴标签
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# 设置图形标题
ax.set_title('Laser line space position')

# 显示图形
plt.show()

# %%
# 创建数据网格
x = np.linspace(-95, 95, 1000)
y = np.linspace(-18, 65, 1000)
X, Y = np.meshgrid(x, y)

# 定义平面方程
Z = 0.04649940105993022*X + 0.7022479002697639*Y +363.0142033514434

# 创建一个三维图形对象
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 绘制平面
ax.plot_surface(X, Y, Z, cmap='viridis')

# 设置坐标轴标签
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# 设置图形标题
ax.set_title('3D Plane')

# 显示图形
plt.show()
